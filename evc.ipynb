# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe =pd.read_csv('Electric_Vehicle_Population_Data.csv')

# %%
dataframe.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P  Thurston    Olympia    WA      98501.0        2023    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           291.0
# 1           Clean Alternative Fuel Vehicle Eligible           150.0
# 2           Clean Alternative Fuel Vehicle Eligible           200.0
# 3           Clean Alternative Fuel Vehicle Eligible            47.0
# 4             Not eligible due to low battery range            23.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  22.0     124535071.0
# 1        0.0                  45.0     102359449.0
# 2        0.0                  33.0     228682037.0
# 3        0.0                  23.0     171566447.0
# 4        0.0                  22.0     234923230.0
#
#                   Vehicle Location  \
# 0  POINT (-122.7474291 47.0821119)
# 1  POINT (-122.0313266 47.6285782)
# 2  POINT (-122.2012521 47.3931814)
# 3     POINT (-122.64177 47.737525)
# 4     POINT (-122.89692 47.043535)
#
#                                 Electric Utility  2020 Census Tract
# 0                         PUGET SOUND ENERGY INC       5.306701e+10
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.303509e+10
# 4                         PUGET SOUND ENERGY INC       5.306701e+10

# %%
dataframe.tail()
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 126001  1C4JJXR61P  Snohomish     Snohomish    WA      98296.0        2023
# 126002  7SAYGDEF6P     Pierce    Gig Harbor    WA      98332.0        2023
# 126003  5YJ3E1EB3M       King     Carnation    WA      98014.0        2021
# 126004  KNDCM3LDXN    Clallam  Port Angeles    WA      98362.0        2022
# 126005  JTDKARFP0H    Whatcom    Bellingham    WA      98226.0        2017
#
#           Make     Model                   Electric Vehicle Type  \
# 126001    JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 126002   TESLA   MODEL Y          Battery Electric Vehicle (BEV)
# 126003   TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 126004     KIA      NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 126005  TOYOTA         P                                     NaN
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 126001              Not eligible due to low battery range            21.0
# 126002  Eligibility unknown as battery range has not b...             0.0
# 126003  Eligibility unknown as battery range has not b...             0.0
# 126004              Not eligible due to low battery range            26.0
# 126005                                                NaN             NaN
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 126001        0.0                   1.0     231160800.0
# 126002        0.0                  26.0     255125755.0
# 126003        0.0                   5.0     138189705.0
# 126004        0.0                  24.0     186153663.0
# 126005        NaN                   NaN             NaN
#
#                        Vehicle Location  \
# 126001    POINT (-122.15134 47.8851158)
# 126002    POINT (-122.589645 47.342345)
# 126003  POINT (-121.9105947 47.6483005)
# 126004    POINT (-123.425565 48.109795)
# 126005                              NaN
#
#                                          Electric Utility  2020 Census Tract
# 126001                             PUGET SOUND ENERGY INC       5.306105e+10
# 126002  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 126003      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 126004  BONNEVILLE POWER ADMINISTRATION||CITY OF PORT ...       5.300900e+10
# 126005                                                NaN                NaN

# %%
dataframe.shape
# Out:
# (126006, 17)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126006 entries, 0 to 126005
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         126006 non-null  object
#  1   County                                             126005 non-null  object
#  2   City                                               126005 non-null  object
#  3   State                                              126006 non-null  object
#  4   Postal Code                                        126005 non-null  float64
#  5   Model Year                                         126006 non-null  int64
#  6   Make                                               126006 non-null  object
#  7   Model                                              126006 non-null  object
#  8   Electric Vehicle Type                              126005 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  126005 non-null  object
#  10  Electric Range                                     126005 non-null  float64
#  11  Base MSRP                                          126005 non-null  float64
#  12  Legislative District                               125836 non-null  float64
#  13  DOL Vehicle ID                                     126005 non-null  float64
#  14  Vehicle Location                                   126002 non-null  object
#  15  Electric Utility                                   126004 non-null  object
#  16  2020 Census Tract                                  126004 non-null  float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 16.3+ MB

# %%
dataframe.select_dtypes(include= 'object').head()
# Out:
#    VIN (1-10)    County       City State    Make    Model  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA   TESLA  MODEL Y
# 1  1N4BZ1CP1K      King  Sammamish    WA  NISSAN     LEAF
# 2  5YJXCDE28G      King       Kent    WA   TESLA  MODEL X
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA   HONDA  CLARITY
# 4  WA1F2AFY4P  Thurston    Olympia    WA    AUDI     Q5 E
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1          Battery Electric Vehicle (BEV)
# 2          Battery Electric Vehicle (BEV)
# 3  Plug-in Hybrid Electric Vehicle (PHEV)
# 4  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# 0           Clean Alternative Fuel Vehicle Eligible
# 1           Clean Alternative Fuel Vehicle Eligible
# 2           Clean Alternative Fuel Vehicle Eligible
# 3           Clean Alternative Fuel Vehicle Eligible
# 4             Not eligible due to low battery range
#
#                   Vehicle Location  \
# 0  POINT (-122.7474291 47.0821119)
# 1  POINT (-122.0313266 47.6285782)
# 2  POINT (-122.2012521 47.3931814)
# 3     POINT (-122.64177 47.737525)
# 4     POINT (-122.89692 47.043535)
#
#                                 Electric Utility
# 0                         PUGET SOUND ENERGY INC
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 3                         PUGET SOUND ENERGY INC
# 4                         PUGET SOUND ENERGY INC
